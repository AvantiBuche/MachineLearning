# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')

# %%
# independent
x = np.array([-1,0,1,2,3,4])
# dependent
y = np.array([-3,-1,1,3,5,7])

# %%
plt.scatter(x,y)
plt.xlabel('Independent')
plt.ylabel('Dependent')
plt.show()

# %%
x = x.reshape(-1,1)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.score(x,y)
# Out:
# 1.0

# %%
plt.scatter(x,y)
plt.plot(x,model.predict(x),color='red')
plt.xlabel('Independent')
plt.ylabel('Dependent')
plt.show()

# %%
# lasso & ridge Regression
from sklearn.linear_model import Ridge
rmodel = Ridge(alpha=5.0) #hyperparameter, 5.0 to add errors, convert overfit to goodfit
rmodel.fit(x,y)
# Out:
# Ridge(alpha=5.0)

# %%
rmodel.score(x,y)
# Out:
# 0.9506172839506173

# %%
plt.scatter(x,y)
plt.plot(x,rmodel.predict(x),color='red')
plt.xlabel('Independent')
plt.ylabel('Dependent')
plt.show()

# %%
from sklearn.linear_model import Lasso
lmodel = Lasso(alpha=0.8)
lmodel.fit(x,y)
lmodel.score(x,y)
# Out:
# 0.9811918367346939

# %%
plt.scatter(x,y)
plt.plot(x,lmodel.predict(x),color='red')
plt.xlabel('Independent')
plt.ylabel('Dependent')
plt.show()

# %%
#Another example for test
dataset=pd.read_csv("sat.csv")
dataset
# Out:
#      SAT   GPA
# 0   1714  2.40
# 1   1664  2.52
# 2   1760  2.54
# 3   1685  2.74
# 4   1693  2.83
# ..   ...   ...
# 79  1936  3.71
# 80  1810  3.71
# 81  1987  3.73
# 82  1962  3.76
# 83  2050  3.81
#
# [84 rows x 2 columns]

# %%
a=dataset.iloc[:,[0]].values
b=dataset.iloc[:,[1]].values

# %%
plt.scatter(a,b)
plt.xlabel('SAT')
plt.ylabel('GPA')
plt.show()

# %%
from sklearn.linear_model import LinearRegression
model1=LinearRegression()
model1.fit(a,b)
# Out:
# LinearRegression()

# %%
model1.score(a,b)
# Out:
# 0.40600391479679765

# %%
plt.scatter(a,b)
plt.plot(a,model1.predict(a),color='yellow')
plt.xlabel('Independent')
plt.ylabel('Dependent')
plt.show()

# %%
# lasso & ridge Regression
from sklearn.linear_model import Ridge
rmodel1 = Ridge(alpha=5.0) #hyperparameter, 5.0 to add errors, convert overfit to goodfit
rmodel1.fit(a,b)
# Out:
# Ridge(alpha=5.0)

# %%
rmodel1.score(a,b)
# Out:
# 0.40600391478445697

# %%
plt.scatter(a,b)
plt.plot(a,rmodel1.predict(a),color='red')
plt.show()

# %%
from sklearn.linear_model import Lasso
lmodel1 = Lasso(alpha=0.8)
lmodel1.fit(a,b)
lmodel1.score(a,b)
# Out:
# 0.40519074588045

# %%
plt.scatter(a,b)
plt.plot(a,lmodel1.predict(a),color='red')
plt.show()
